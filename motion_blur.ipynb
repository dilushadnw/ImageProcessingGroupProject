# %%
import cv2
import matplotlib.pyplot as plt

# Read original frame
frame = cv2.imread("frame_9.jpg")

# Convert to grayscale
gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

plt.figure(figsize=(10,5))

plt.subplot(1,2,1)
plt.title("Original Frame")
plt.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))

plt.subplot(1,2,2)
plt.title("Grayscale Frame")
plt.imshow(gray, cmap='gray')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_28836\1455841116.py in <module>
#       6
#       7 # Convert to grayscale
# ----> 8 gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
#       9
#      10 plt.figure(figsize=(10,5))
#
# error: OpenCV(4.12.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
